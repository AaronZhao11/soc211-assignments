// %% [markdown]
// ## Research assignment 2
//
// Aaron Zhao
//
// Immigrant Attitudes to the United States Based On Humanitarian Level of Home Country
//
// Feb 8 2024

// %% [markdown]
// ### 1. Write a paragraph about your hypotheses
//
// [Your answer here should explain:
// 1. What are your dependent variables? Why do they interest you?
//
// My dependet varialbe is people (the respondents of GSS, which are American citizens)'s confidence level in the American Education system. They interest me because I am very interested in the differences in attitudes between immigrants towards the United States in comparision to native born citizens. This would be a first step in determining that relationship, starting from participants' confidence level in education in relation to their educational level, with the immigration status being the control variable.
//
// 2. What are your independent variables? What direction to you hypothesize will be the relationship between your dependent variable and your dependent variables?
//
// My independent variable is the educational level of the participants. I hypothesize that the higher the educational attainment of participants (from both immigrants and native born citizens) the higher their confidence in education wil be.
//
// 3. Why do you think your dependent variables are associated with your independent variables?
//
// The reason why I believe my dependent variable is associated with my independent variable is because having been educated, the respondents must have a positive view on education, even if not I assume people who are educated may poesses some form of pride for being educated, thus increasing their confidence in the educational system (thus at the same time validating themselves).
//
// 4. What are your control variables? Do you think they will show any spurious, intervening, or interactive relationships? Why?]
//
// My control variable would be the participants'status as a citizen (weather or not they are immigrants or native born). This would be an intervening control variable because it will follow the independent variable (education attinment), preceding the dependent variable (confidence level in education) in this succession sequence.

// %% [markdown]
// ### 1. Setting up your session
//
// In the code cell below, do the following:
//
// 1. set current directory
// 2. set more off
// 3. create log file
// 4. download the data from its source if it's available online
// 5. read the data in [preferably only variables you are going to use]

// %% [markdown]
// cd "/Users/aaronzhao/Desktop/Desktop/Grad_Stats_II/soc211assignments"

// %%
cd "/Users/aaronzhao/Desktop/Desktop/Grad_Stats_II/soc211assignments"
// Out:
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>
// /Users/aaronzhao/Desktop/Desktop/Grad_Stats_II/soc211assignments

// %%
set more off
// Out:
// (-set more- irrelevant in this version of Stata)

// %%
log using "Log for Research Assignment 2.log", replace
// Out:
// -------------------------------------------------------------------------------
//       name:  <unnamed>
//        log:  /Users/aaronzhao/Desktop/Desktop/Grad_Stats_II/soc211assignments/L
// > og for Research Assignment 2.log
//   log type:  text
//  opened on:  12 Feb 2024, 22:38:12

// %%
set maxvar 120000

// %%
use "/Users/aaronzhao/Desktop/Desktop/Grad_Stats_II/soc211assignments/gss7222_r2 copy.dta"

// %% [markdown]
// ### 2. Browse the data
//
// Do the following in separate cells. Do do these in separate cells, you will need to use the right click "split cell" option:
//
// 1. Use "describe" to print details about the dataset
// 2. Print the heads and tables of the data using the appropriate magic
// 3. label the unique identifier variable
// 4. Generate a frequency table to show the N for each unit of time if there is data for multiple units in time
// 5. Check for missing data overall and within key categories of analysis (time, independent or dependent variable categories, etc)
// 6. use summarize to create a table with summary statistics for each variable you plan to analyze

// %%
describe
// Out:
// Contains data from /Users/aaronzhao/Desktop/Desktop/Grad_Stats_II/soc211assignm
// > ents/gss7222_r2 copy.dta
//  Observations:        72,390
//     Variables:         6,693                  14 Nov 2023 22:19
// -------------------------------------------------------------------------------
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// -------------------------------------------------------------------------------
// year            int     %29.0g     COUNTMISS
//                                               gss year for this respondent
// id              int     %8.0g                 respondent id number
// wrkstat         byte    %74.0g     WRKSTAT    labor force status
// hrs1            byte    %29.0g     WKHRS      number of hours worked last week
// hrs2            byte    %29.0g     WKHRS      number of hours usually work a
//                                                 week
// ...

// %%
*describe 
describe coneduc educ born
//age, educ, sex, born (Were you born in this country?), parborn (Were both your parents born in this country? (IF THE RESPONDENT IS UNCERTAIN OF PARENT,
//USE SAM E PERSONS AS IN PAOCC16 to PAIND16, PAEDUC, MAEDUC, PADEG, AND MADEG. id 是 Identifier Variable))
// Out:
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// -------------------------------------------------------------------------------
// coneduc         byte    %29.0g     INSTCONF   confidence in education
// educ            byte    %29.0g     EDUC       highest year of school completed
// born            byte    %29.0g     YESNO      was r born in this country

// %%
codebook coneduc educ born
// Out:
// -------------------------------------------------------------------------------
// coneduc                                                 confidence in education
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: INSTCONF
//
//                  Range: [1,3]                         Units: 1
//          Unique values: 3                         Missing .: 0/72,390
//        Unique mv codes: 4                        Missing .*: 23,990/72,390
//
//             Tabulation: Freq.   Numeric  Label
//                        13,856         1  a great deal
//                        27,230         2  only some
//                         7,314         3  hardly any
//                           555        .d  don't know
//                        23,292        .i  iap
//                           122        .n  no answer
//                            21        .s  skipped on web
//
// ...

// %%
sort id
quietly by id: gen dup = cond(_N==1, 0, _n)

// %%
tab dup
// Out:
//         dup |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |        145        0.20        0.20
//           1 |      4,365        6.03        6.23
//           2 |      4,365        6.03       12.26
//           3 |      3,504        4.84       17.10
//           4 |      3,214        4.44       21.54
//           5 |      2,901        4.01       25.55
//           6 |      2,863        3.95       29.50
//           7 |      2,831        3.91       33.41
//           8 |      2,816        3.89       37.30
//           9 |      2,804        3.87       41.18
//          10 |      2,746        3.79       44.97
//          11 |      2,523        3.49       48.46
//          12 |      2,353        3.25       51.71
//          13 |      2,324        3.21       54.92
//          14 |      2,099        2.90       57.82
//          15 |      1,993        2.75       60.57
//          16 |      1,774        2.45       63.02
// ...

// %%
label variable id "Respodent's ID Number"

// %%
codebook id
// Out:
// -------------------------------------------------------------------------------
// id                                                        Respodent's ID Number
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (int)
//
//                  Range: [1,4510]                      Units: 1
//          Unique values: 4,510                     Missing .: 0/72,390
//
//                   Mean:  1241.8
//              Std. dev.: 912.273
//
//            Percentiles:     10%       25%       50%       75%       90%
//                             214       534      1083      1722      2533

// %%
tab coneduc, missing
tab educ, missing
tab born, missing
// Out:
//       confidence in education |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
//                  a great deal |     13,856       19.14       19.14
//                     only some |     27,230       37.62       56.76
//                    hardly any |      7,314       10.10       66.86
//                    don't know |        555        0.77       67.63
//                           iap |     23,292       32.18       99.80
//                     no answer |        122        0.17       99.97
//                skipped on web |         21        0.03      100.00
// ------------------------------+-----------------------------------
//                         Total |     72,390      100.00
//
//        highest year of school |
//                     completed |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
// ...

// %%
summarize coneduc, detail
// Out:
//                    confidence in education
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%            1              1
//  5%            1              1
// 10%            1              1       Obs              48,400
// 25%            1              1       Sum of wgt.      48,400
//
// 50%            2                      Mean           1.864835
//                         Largest       Std. dev.      .6474069
// 75%            2              3
// 90%            3              3       Variance       .4191357
// 95%            3              3       Skewness       .1373112
// 99%            3              3       Kurtosis       2.341146

// %% [markdown]
// ### 3. Write a note summarizing what you learned from browsing the data
//
// The data is cross sectional data because I have data from many units (confidence level, education attainment, born), at one point in time.
// The years represented by my data is from 2022, the data extracted is from the GSS.
// The social factors that I am interested in looking at have nominal variables.
// My dependent variable is numeric, the mean is 1.86.

// %% [markdown]
// ### 4. Create univariate histograms of interval ratio variables you plan to analyze.
//
// Write at least 3 forloops to generate histograms for all the variables you plan to analyze. Create titles for each histogram that notes whether it is a dependent, independent, or control variable (you can also note in titles whether control vars control for spurious, intervening, or interactive relationships). Begin with your dependent variables. Then make a note below to describe the shapes of the distributions and their implications for your study.
//
// [your note here]

// %%
histogram coneduc, frequency title("Confident Level in Education (Dependent Variable)")
// Out:
// (bin=46, start=1, width=.04347826)

// %%
histogram educ, frequency title("Education of Respondents (Independent Variable)")
// Out:
// (bin=48, start=0, width=.41666667)

// %%
histogram born, frequency title("Respondents' Home Country (Control Intervening Variable)")
// Out:
// (bin=47, start=1, width=.0212766)

// %%
foreach x of varlist coneduc educ born {
    histogram `x'
}
// Out:
// (bin=46, start=1, width=.04347826)
// (bin=48, start=0, width=.41666667)
// (bin=47, start=1, width=.0212766)

// %% [markdown]
// ### 5. Create univariate count and % frequency tables for all categorical (nominal) variables you plan to analyze
//
// Again, use forloops. Then write a note below with a narrative summary of the distributions and their implications for your study.
//
// [your note here]

// %%
foreach x of varlist coneduc educ born {
    replace `x'=. if `x'==.i | `x'==.n | `x'==.d
    tab `x', missing
}
// Out:
// (23,969 real changes made, 23,969 to missing)
//
//       confidence in education |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
//                  a great deal |     13,856       19.14       19.14
//                     only some |     27,230       37.62       56.76
//                    hardly any |      7,314       10.10       66.86
//                             . |     23,969       33.11       99.97
//                skipped on web |         21        0.03      100.00
// ------------------------------+-----------------------------------
//                         Total |     72,390      100.00
// (263 real changes made, 263 to missing)
//
//        highest year of school |
//                     completed |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
//           no formal schooling |        177        0.24        0.24
// ...

// %% [markdown]
// ### 6. Make a relevant bivariate table and graph for your study
//
// Make the appropriate a) bivariate table and b) graph dependening on whether your dependent variable is nominal/categorical or interval ratio. If your dependent variable is nominal, make sure it is the row variable in the table. If your independent variable is interval ratio, convert it into an ordinal variable by creating a new variable with 3 to 5 categories each with an equal range of the interval ratio variable. Then use the new ordinal variable as your independent variable in the bivariate table and graph.

// %%
codebook coneduc
// Out:
// -------------------------------------------------------------------------------
// coneduc                                                 confidence in education
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: INSTCONF
//
//                  Range: [1,3]                         Units: 1
//          Unique values: 3                         Missing .: 23,969/72,390
//        Unique mv codes: 2                        Missing .*: 21/72,390
//
//             Tabulation: Freq.   Numeric  Label
//                        13,856         1  a great deal
//                        27,230         2  only some
//                         7,314         3  hardly any
//                        23,969         .
//                            21        .s  skipped on web

// %%
graph hbar (mean) coneduc, over(educ) title("Confidence in Education & Education Level")

// %% [markdown]
// ### 7. Create partial bivariate tables and graphs
//
// For the bivariate table and graph you made for problem 6, split both into partial tables and graphs using one of your nominal/categorical control variables. If your control variable is interval ratio, convert it into an ordinal variable by creating a variable with 3 to 5 categories each with an equal range of the interval ratio variable.  Then use the new ordinal variable as your control variable to create the partial tables and graphs.

// %%
codebook sex
sum sex
// Out:
// -------------------------------------------------------------------------------
// sex                                                             respondents sex
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: GENDER
//
//                  Range: [1,2]                         Units: 1
//          Unique values: 2                         Missing .: 0/72,390
//        Unique mv codes: 4                        Missing .*: 112/72,390
//
//             Tabulation: Freq.   Numeric  Label
//                        31,977         1  male
//                        40,301         2  female
//                             8        .d  don't know
//                            19        .i  iap
//                            80        .n  no answer
//                             5        .s  skipped on web
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// ...

// %%
gen sex_1a=sex
replace sex_1a=1 if sex_1a==1
replace sex_1a=2 if sex_1a==2
replace sex_1a=0 if sex_1a==.n
replace sex_1a=0 if sex_1a==.i
replace sex_1a=0 if sex_1a==.d
replace sex_1a=0 if sex_1a==.s

label variable sex_1a "what is the sex of respondents"
label define sex_1a 1 "Male" 2 "Female" 0 "No response"
label values sex_1a sex_1a

codebook sex_1a
// Out:
// (112 missing values generated)
// (0 real changes made)
// (0 real changes made)
// (80 real changes made)
// (19 real changes made)
// (8 real changes made)
// (5 real changes made)
//
// -------------------------------------------------------------------------------
// sex_1a                                           what is the sex of respondents
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (float)
//                  Label: sex_1a
//
//                  Range: [0,2]                         Units: 1
//          Unique values: 3                         Missing .: 0/72,390
//
//             Tabulation: Freq.   Numeric  Label
//                           112         0  No response
//                        31,977         1  Male
//                        40,301         2  Female

// %%
graph hbar (mean) coneduc, over(educ) by(sex_1a) title("Partial Bivariate Graph")

// %% [markdown]
// ### Interpret of your bivariate and partial tables and graphs
//
// Is there a relationship between your dependent and independent variables? Is it weak, strong, or non-existent? Do adding controls reveal any spurious, intervening, or interactive relationships? Do they conform with your hypotheses? If not, do you have any ideas for why and how you might test the reason why?
//
// There is a relationship between my dependent variable (confidence in educational system) and my independent variable (educational attainment). There is a strong relationship, but it is very interesting: people from the two extreme spectrums both have relatively high confidence in the educational system, with participants who are more educated having a higher confidence than the non-educated participants. The confidence in educational system is the lowest amongst people who have a little education, and it gradually increases as people become more and more educated. Adding the control did not reveal any spurious, intervening, or interactive relationship, or at least it did not appear to me that the control has revealed any relatinships. They do not entirely confrom with my hypotheses. My educated guess would be that people who have no educational experience has a higher confidence in the educational system because they have high hopes and expectations for this institution that they did not participate in. For people who are only a little educated, they may have dropped out of the educational system due to various reasons, resulting in a bad experience and confidence in the educational system. Those who are highly educated may poesses some form of pride for being educated, thus increasing their confidence in the educational system (thus at the same time validating themselves). To test this reason, I may have to obtain data through the implementation of survey questions I personally draft that specifically address this phenomenon.

// %%
log close
// Out:
//       name:  <unnamed>
//        log:  /Users/aaronzhao/Desktop/Desktop/Grad_Stats_II/soc211assignments/L
// > og for Research Assignment 2.log
//   log type:  text
//  closed on:  12 Feb 2024, 22:38:27
// -------------------------------------------------------------------------------
